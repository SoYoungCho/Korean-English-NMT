# %% [markdown]
# ## 1. 데이터 불러오기

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random

# %%
data1 = pd.read_csv('C:/Users/Soyoung Cho/Desktop/NMT Project/dataset/train.csv')
data2 = pd.read_csv('C:/Users/Soyoung Cho/Desktop/NMT Project/dataset/test.csv')
data3 = pd.read_csv('C:/Users/Soyoung Cho/Desktop/NMT Project/dataset/tatoeba_data.csv')

# %%
data = pd.concat([data1, data2, data3])

# %%
data = data.reset_index(drop=True) # 0~20만, 0~20만 이런 인덱스까지 concat 되었던 것을 초기화, 다시 인덱스 주었다

# %%
data
# Out:
#                                                     Korean  \
# 0        경기도가 평화시대를 맞아 통일문제를 보다 쉽고 재미있게 다가갈 수 있도록 통일전문 ...
# 1        우선 현재 강원 동해안을 제외한 중부 지방과 호남 서해안에 약하게 눈이 내리거나 눈...
# 2        아직 구체적인 의제가 확정된 것은 아니지만 지난 19일 한미 국방부가 발표한 UFG...
# 3                   이시기의 남자아이에게는 레고 시티나 레고 닌자고 시리즈를 추천합니다.
# 4        손 대표로선 이날 지도부 회의에서 최고위원들을 중심으로 “사퇴하라”는 요구가 나온 ...
# ...                                                    ...
# 1606021                                              내일 와.
# 1606022                                      나도 너랑 같은 처지야.
# 1606023                               내가 끔찍한 실수를 저지른 것 같아.
# 1606024                          그 사람은 자기 이름을 싸인하는 법조차 몰라.
# 1606025                             톰은 메리라는 캐나다 여성이랑 결혼했어.
#
#                                                    English
# 0        Gyeonggi-do Province will collaborate with the...
# 1        First of all, it is currently snowing slightly...
# 2        The specific agenda has not been decided yet, ...
# 3        Lego City and the series Lego Ninjago are reco...
# 4        The representive Sohn apparently chose to make...
# ...                                                    ...
# 1606021                                     Come tomorrow.
# 1606022                       I'm in the same boat as you.
# 1606023              I think I've made a horrible mistake.
# 1606024        He does not even know how to sign his name.
# 1606025     Tom is married to a Canadian woman named Mary.
#
# [1606026 rows x 2 columns]

# %%
Kor_list = list(data['Korean']) #모든 한글 문장이 담긴 리스트
Eng_list = list(data['English']) #모든 영어 문장이 담긴 리스트

print(Kor_list[:5])
print("\n")
print(Eng_list[:5])
# Out:
# ['경기도가 평화시대를 맞아 통일문제를 보다 쉽고 재미있게 다가갈 수 있도록 통일전문 팟캐스트 <남북상열지사>와 콜라보레이션을 진행한다.', '우선 현재 강원 동해안을 제외한 중부 지방과 호남 서해안에 약하게 눈이 내리거나 눈발이 조금 날리고 있습니다.', '아직 구체적인 의제가 확정된 것은 아니지만 지난 19일 한미 국방부가 발표한 UFG 연합훈련중단에 따른 세부협의를 진행할 것으로 관측된다.', '이시기의 남자아이에게는 레고 시티나 레고 닌자고 시리즈를 추천합니다.', '손 대표로선 이날 지도부 회의에서 최고위원들을 중심으로 “사퇴하라”는 요구가 나온 가운데 정면 돌파를 택한 셈이다.']
#
#
# ['Gyeonggi-do Province will collaborate with the unification special podcast <Love Song Between North and South Korea> in order to approach the issue of unification in easier and more fun ways in the time of peace.', 'First of all, it is currently snowing slightly or snow flutters lightly son the central region and the west coast of Honam except the east coast of Gangwon.', 'The specific agenda has not been decided yet, but it is expected to proceed with detailed consultations following the suspension of the UFG coalition training announced by the US Department of Defense on the 19th.', 'Lego City and the series Lego Ninjago are recommended to the boys of this age.', 'The representive Sohn apparently chose to make a head-on breakthrough during the leadership meeting amid the calls for his resignation led by the supreme council members.']

# %%
result = list(zip(Kor_list,Eng_list))

random.shuffle(result)
result 

Kor_list, Eng_list = zip(*result)

# %%
dict_ = {"Korean": [], "English" : []}
dict_["Korean"] = Kor_list
dict_["English"] = Eng_list

# %%
data = pd.DataFrame(dict_)
data
# Out:
#                                                     Korean  \
# 0        소수의 부유한 사람들을 위한 경제가 아니라 내가 속한 공동체에 보탬이 되는 경제 틀...
# 1                           조사가 길어지면서 잦은 현장조사에 대해 비판이 나온다.
# 2        그가 1989년 미국에서 출간한 ‘디스커버링(Discovering)’은 위대한 과학...
# 3                            당신이 생각했던것 처럼 병원비가 많이 나온건 알아요.
# 4        전반 8분, 상대 슈팅이 골대에 맞는 행운으로 위기를 넘긴 벨기에는 5분 뒤 행운의...
# ...                                                    ...
# 1606021  이와 달리 취업이라는 조건을 달지 않고 영유아를 양육하는 여성에게 보조금을 줄 경우...
# 1606022  경기도는 금번 투자상담회 이외에도 금년 하반기에 러시아에서 투자설명회 개최를 검토하...
# 1606023  공사는 1차 채용된 직원 이외의 잔여직원(53명)을 조속히 채용할 계획이며, 새만금...
# 1606024                        나는 내가 어렸을 적의 사진을 몇 장 찾았습니다.
# 1606025  서울에 위치하는 지식산업센터들의 분양가가 급상승하며 이에 부담을 느낀 기업들이 경기...
#
#                                                    English
# 0        The city can do a better job of building an ec...
# 1        As the investigation drags on, criticism comes...
# 2        "Discovering," which he published in 1989 in t...
# 3        I know the hospital fee was really high as you...
# 4        In the eight minutes of the first half, Belgiu...
# ...                                                    ...
# 1606021  On the other hand, when subsidies were given t...
# 1606022  In addition to this investment consultation me...
# 1606023  The corporation plans to hire remaining employ...
# 1606024         I found some photos from when I was young.
# 1606025  As the parcel prices of the knowledge industry...
#
# [1606026 rows x 2 columns]

# %% [markdown]
# ## 2. 데이터 중복 검사 및 제거

# %%
data.describe()
# Out:
#              Korean                                            English
# count       1606026                                            1606026
# unique      1603111                                            1601859
# top     뭔가 할 말이 있니?  Korea went to the public hearing with everyone...
# freq              5                                                 27

# %%
data.duplicated().sum()
# Out:
# 2497

# %%
data = data.drop_duplicates()

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data = data.reset_index(drop=True) # 0~20만, 0~20만 이런 인덱스까지 concat 되었던 것을 초기화, 다시 인덱스 주었다

# %%
data
# Out:
#                                                     Korean  \
# 0        소수의 부유한 사람들을 위한 경제가 아니라 내가 속한 공동체에 보탬이 되는 경제 틀...
# 1                           조사가 길어지면서 잦은 현장조사에 대해 비판이 나온다.
# 2        그가 1989년 미국에서 출간한 ‘디스커버링(Discovering)’은 위대한 과학...
# 3                            당신이 생각했던것 처럼 병원비가 많이 나온건 알아요.
# 4        전반 8분, 상대 슈팅이 골대에 맞는 행운으로 위기를 넘긴 벨기에는 5분 뒤 행운의...
# ...                                                    ...
# 1603524  이와 달리 취업이라는 조건을 달지 않고 영유아를 양육하는 여성에게 보조금을 줄 경우...
# 1603525  경기도는 금번 투자상담회 이외에도 금년 하반기에 러시아에서 투자설명회 개최를 검토하...
# 1603526  공사는 1차 채용된 직원 이외의 잔여직원(53명)을 조속히 채용할 계획이며, 새만금...
# 1603527                        나는 내가 어렸을 적의 사진을 몇 장 찾았습니다.
# 1603528  서울에 위치하는 지식산업센터들의 분양가가 급상승하며 이에 부담을 느낀 기업들이 경기...
#
#                                                    English
# 0        The city can do a better job of building an ec...
# 1        As the investigation drags on, criticism comes...
# 2        "Discovering," which he published in 1989 in t...
# 3        I know the hospital fee was really high as you...
# 4        In the eight minutes of the first half, Belgiu...
# ...                                                    ...
# 1603524  On the other hand, when subsidies were given t...
# 1603525  In addition to this investment consultation me...
# 1603526  The corporation plans to hire remaining employ...
# 1603527         I found some photos from when I was young.
# 1603528  As the parcel prices of the knowledge industry...
#
# [1603529 rows x 2 columns]

# %%
#data.to_csv("datalist.csv", encoding = 'utf-8-sig', index = False, mode = "w")

# %% [markdown]
# ## 3. 문장별 단어 개수 파악 & 문제 파악

# %% [markdown]
# ### (1) 단어 개수 별 정렬해 데이터 확인 & 문제 수정

# %%
kor_sorted = data.sort_values(by=['Korean_word_count'], axis=0, ascending=False)

# %%
kor_sorted = kor_sorted.reset_index(drop=True)
kor_sorted.head()
# Out:
#                                               Korean  \
# 0  의심의 여지 없이 세상에는 어떤 남자이든 정확히 딱 알맞는 여자와 결혼하거나 그 반...
# 1  일단의 토지면적이 특별시·광역시 및 시지역에서 1,000제곱미터 이하, 그 밖의 지...
# 2  제8조의2(과태료의 부과 및 징수) ① 제8조제1항의 요구를 받은 자가 이에 따를 ...
# 3  부칙 제2조「표 1」규정의 시행으로 감축되는 정원 27명(집행기관의 정원 27명)에...
# 4  「옥외광고물 등의 관리와 옥외광고산업 진흥에 관한 법률 시행령」(이하 “영”이라 한...
#
#                                              English  Korean_word_count  \
# 0  Doubtless there exists in this world precisely...                 89
# 1  Where land that has buildings that are not own...                 78
# 2  Article 8-2 (Imposition and Collection of Fine...                 71
# 3  Where there the current employees are in exces...                 64
# 4  Where filing an application for permission in ...                 62
#
#    English_word_count
# 0                 101
# 1                 165
# 2                 139
# 3                 158
# 4                 122

# %%
kor_sorted[0:10]
# Out:
#                                               Korean  \
# 0  의심의 여지 없이 세상에는 어떤 남자이든 정확히 딱 알맞는 여자와 결혼하거나 그 반...
# 1  일단의 토지면적이 특별시·광역시 및 시지역에서 1,000제곱미터 이하, 그 밖의 지...
# 2  제8조의2(과태료의 부과 및 징수) ① 제8조제1항의 요구를 받은 자가 이에 따를 ...
# 3  부칙 제2조「표 1」규정의 시행으로 감축되는 정원 27명(집행기관의 정원 27명)에...
# 4  「옥외광고물 등의 관리와 옥외광고산업 진흥에 관한 법률 시행령」(이하 “영”이라 한...
# 5  구청장은 신·재생에너지의 보급 확대를 위하여 행정재산 및 일반재산을 사용·수익허가 ...
# 6  “음식물류 폐기물 다량배출사업장”이란 「폐기물관리법 시행령」 제8조의4에서 정한 음...
# 7  이 조례에 따라 구세를 감면받고자 하는 자는 「지방세특례제한법 시행규칙」 별지 제1...
# 8  서울특별시 노원구청장(이하 “구청장”이라 한다)은 위임받은 서울특별시 시세(이하 “...
# 9  구청장은 「비영리민간단체지원법」에 따른 비영리 민간단체, 「민법」에 따른 비영리 법...
#
#                                              English  Korean_word_count  \
# 0  Doubtless there exists in this world precisely...                 89
# 1  Where land that has buildings that are not own...                 78
# 2  Article 8-2 (Imposition and Collection of Fine...                 71
# 3  Where there the current employees are in exces...                 64
# 4  Where filing an application for permission in ...                 62
# 5  In order to increase the supply of new and ren...                 61
# 6  The term "Business sites discharging large amo...                 59
# 7  Any person who intends to receive a reduction ...                 59
# 8  The head of Nowon-gu Seoul Metropolitan Govern...                 56
# 9  The head of the Gu may designate organizations...                 54
#
#    English_word_count
# 0                 101
# 1                 165
# 2                 139
# 3                 158
# 4                 122
# 5                 133
# 6                 141
# 7                 148
# 8                 156
# 9                  99

# %%
kor_sorted[-10:]
# Out:
#                                              Korean  \
# 1603519                                        잘했어!
# 1603520                                        계속해.
# 1603521                                    예약하셨습니까?
# 1603522                                         잠깐!
# 1603523  러셀은, 육군에게 대동하는 특파원으로서 크리미아 전쟁에 파견되어 취재했어요.
# 1603524                      고객님께서 문의하신 사항 잘 확인했어요.
# 1603525                                500,000원입니다.
# 1603526                                      시도해볼게.
# 1603527                                        도와줘!
# 1603528                                      무료입니까?
#
#                                                    English  Korean_word_count  \
# 1603519                                          Good job!                  1
# 1603520                                          Go ahead.                  1
# 1603521                       Did you make an appointment?                  1
# 1603522                                              Wait!                  1
# 1603523  Russell was dispatched to the Cremean War as a...                  1
# 1603524                We have fully checked your inquiry.                  1
# 1603525                             It's 500 thousand won.                  1
# 1603526                                             I try.                  1
# 1603527                                           Help me!                  1
# 1603528                                        Is it free?                  1
#
#          English_word_count
# 1603519                   2
# 1603520                   2
# 1603521                   5
# 1603522                   1
# 1603523                  13
# 1603524                   6
# 1603525                   4
# 1603526                   2
# 1603527                   2
# 1603528                   3

# %% [markdown]
# #### 문제 발견 및 수정, 데이터 재저장

# %%
kor_sorted["Korean"][1603523]
# Out:
# '러셀은,\xa0육군에게\xa0대동하는\xa0특파원으로서\xa0크리미아\xa0전쟁에\xa0파견되어\xa0취재했어요.'

# %%
kor_sorted["Korean"][1603524]
# Out:
# '고객님께서\xa0문의하신\xa0사항\xa0잘\xa0확인했어요.'

# %%
kor_sorted["Korean"][1603515]
# Out:
# '겉만\xa0보고\xa0판단하지\xa0마세요.'

# %% [markdown]
# 중간의 \xa0 때문에 한 문장이 한 단어로 인식 되었었다. 전체 dataset의 \xa0 를 " " 로 대체해준다.
# 다시 word를 카운트 해준다.

# %%
data.replace("\xa0", " ", regex=True, inplace=True)

# %%
#del data['Korean_word_count']
#del data['English_word_count']
#data.to_csv("C:/Users/Soyoung Cho/Desktop/NMT Project/dataset/datalist_modified.csv", encoding = 'utf-8-sig', index = False, mode = "w")

# %%
data
# Out:
#                                                     Korean  \
# 0        소수의 부유한 사람들을 위한 경제가 아니라 내가 속한 공동체에 보탬이 되는 경제 틀...
# 1                           조사가 길어지면서 잦은 현장조사에 대해 비판이 나온다.
# 2        그가 1989년 미국에서 출간한 ‘디스커버링(Discovering)’은 위대한 과학...
# 3                            당신이 생각했던것 처럼 병원비가 많이 나온건 알아요.
# 4        전반 8분, 상대 슈팅이 골대에 맞는 행운으로 위기를 넘긴 벨기에는 5분 뒤 행운의...
# ...                                                    ...
# 1603524  이와 달리 취업이라는 조건을 달지 않고 영유아를 양육하는 여성에게 보조금을 줄 경우...
# 1603525  경기도는 금번 투자상담회 이외에도 금년 하반기에 러시아에서 투자설명회 개최를 검토하...
# 1603526  공사는 1차 채용된 직원 이외의 잔여직원(53명)을 조속히 채용할 계획이며, 새만금...
# 1603527                        나는 내가 어렸을 적의 사진을 몇 장 찾았습니다.
# 1603528  서울에 위치하는 지식산업센터들의 분양가가 급상승하며 이에 부담을 느낀 기업들이 경기...
#
#                                                    English
# 0        The city can do a better job of building an ec...
# 1        As the investigation drags on, criticism comes...
# 2        "Discovering," which he published in 1989 in t...
# 3        I know the hospital fee was really high as you...
# 4        In the eight minutes of the first half, Belgiu...
# ...                                                    ...
# 1603524  On the other hand, when subsidies were given t...
# 1603525  In addition to this investment consultation me...
# 1603526  The corporation plans to hire remaining employ...
# 1603527         I found some photos from when I was young.
# 1603528  As the parcel prices of the knowledge industry...
#
# [1603529 rows x 2 columns]

# %% [markdown]
# ---

# %%
kor_word_cnt = []
eng_word_cnt = []
for i in range(len(data)):
    kor_word_cnt.append(len(data['Korean'][i].split(" ")))
    eng_word_cnt.append(len(data['English'][i].split(" ")))

# %%
data["Korean_word_count"] = kor_word_cnt
data["English_word_count"] = eng_word_cnt

# %% [markdown]
# ---

# %% [markdown]
# ### (2) 한글 문장 단어 개수 파악

# %%
kor_sorted = data.sort_values(by=['Korean_word_count'], axis=0, ascending=False)

# %%
kor_sorted = kor_sorted.reset_index(drop=True)
kor_sorted.head()
# Out:
#                                               Korean  \
# 0  의심의 여지 없이 세상에는 어떤 남자이든 정확히 딱 알맞는 여자와 결혼하거나 그 반...
# 1  일단의 토지면적이 특별시·광역시 및 시지역에서 1,000제곱미터 이하, 그 밖의 지...
# 2  제8조의2(과태료의 부과 및 징수) ① 제8조제1항의 요구를 받은 자가 이에 따를 ...
# 3  부칙 제2조「표 1」규정의 시행으로 감축되는 정원 27명(집행기관의 정원 27명)에...
# 4  「옥외광고물 등의 관리와 옥외광고산업 진흥에 관한 법률 시행령」(이하 “영”이라 한...
#
#                                              English  Korean_word_count  \
# 0  Doubtless there exists in this world precisely...                 89
# 1  Where land that has buildings that are not own...                 78
# 2  Article 8-2 (Imposition and Collection of Fine...                 71
# 3  Where there the current employees are in exces...                 64
# 4  Where filing an application for permission in ...                 62
#
#    English_word_count
# 0                 101
# 1                 165
# 2                 139
# 3                 158
# 4                 122

# %%
kor_sorted[-110:-90]
# Out:
#                           Korean                                      English  \
# 1603419                     도와줘!                                     Help me!
# 1603420                     일어나!                                     Wake up!
# 1603421                    알겠어요.                                 That's fine.
# 1603422                     진정해.                                       Relax.
# 1603423                      없다.                            There aren't any.
# 1603424                  환급되었나요?                              Is it refunded?
# 1603425                    이해했어.                                I understood.
# 1603426                     확실해?                     Are you sure about that?
# 1603427  당신과같이하면서거의잠들뻔한것도너무미안해요.  Sorry for nearly falling asleep on you too.
# 1603428                   입조심해라.                         Watch your language.
# 1603429                    동작하네.                                    It works.
# 1603430                     둘러봐.                                 Look around.
# 1603431                      알아.                                      I know.
# 1603432                     떨려요.                                 I'm nervous.
# 1603433                     불렀니?                                  You called?
# 1603434                     축하해!                             Congratulations!
# 1603435                     진정해!                                    Cool off!
# 1603436                    긴장돼요.                                 I'm nervous.
# 1603437                    시끄러워!                                     Shut up!
# 1603438                      어서!                                     Come on!
#
#          Korean_word_count  English_word_count
# 1603419                  1                   2
# 1603420                  1                   2
# 1603421                  1                   2
# 1603422                  1                   1
# 1603423                  1                   3
# 1603424                  1                   3
# 1603425                  1                   2
# 1603426                  1                   5
# 1603427                  1                   8
# 1603428                  1                   3
# 1603429                  1                   2
# 1603430                  1                   2
# 1603431                  1                   2
# 1603432                  1                   2
# 1603433                  1                   2
# 1603434                  1                   1
# 1603435                  1                   2
# 1603436                  1                   2
# 1603437                  1                   2
# 1603438                  1                   2

# %%
kor_sorted["Korean"][1603427]
# Out:
# '당신과같이하면서거의잠들뻔한것도너무미안해요.'

# %%
kor_sorted[-130:-110]
# Out:
#                              Korean  \
# 1603399                         가자!
# 1603400                        외로워.
# 1603401                     문제없습니다.
# 1603402                        조심해!
# 1603403                         힘내!
# 1603404                        준비해.
# 1603405                       작동하네.
# 1603406                        진정해.
# 1603407                         점프!
# 1603408                        기다려.
# 1603409                       건너뛰어.
# 1603410                    수정해드릴게요.
# 1603411                       끔찍해라!
# 1603412                      신경쓰지마.
# 1603413                        도와줘!
# 1603414                       진심이야?
# 1603415  호날두의국적은포르투갈이고레알마드리드에서뛰고있다.
# 1603416                         멋져!
# 1603417                        안아줘.
# 1603418                         슬퍼.
#
#                                                    English  Korean_word_count  \
# 1603399                                          Let's go!                  1
# 1603400                                     I feel lonely.                  1
# 1603401                                        No problem.                  1
# 1603402                                          Look out!                  1
# 1603403                                          Cheer up!                  1
# 1603404                                         Get ready.                  1
# 1603405                                          It works.                  1
# 1603406                                         Calm down.                  1
# 1603407                                              Jump!                  1
# 1603408                                              Wait.                  1
# 1603409                                           Skip it.                  1
# 1603410                                  I will change it.                  1
# 1603411                                         How awful!                  1
# 1603412                                        Never mind!                  1
# 1603413                                              Help!                  1
# 1603414                                         Seriously?                  1
# 1603415  Ronaldo is from Portugal and he plays for Real...                  1
# 1603416                                         Wonderful!                  1
# 1603417                                            Hug me.                  1
# 1603418                                           I'm sad.                  1
#
#          English_word_count
# 1603399                   2
# 1603400                   3
# 1603401                   2
# 1603402                   2
# 1603403                   2
# 1603404                   2
# 1603405                   2
# 1603406                   2
# 1603407                   1
# 1603408                   1
# 1603409                   2
# 1603410                   4
# 1603411                   2
# 1603412                   2
# 1603413                   1
# 1603414                   1
# 1603415                  10
# 1603416                   1
# 1603417                   2
# 1603418                   2

# %% [markdown]
# 위와 같이 띄어쓰기가 아예 이루어지지 않은 문장은 어떻게 해야할지 고민 필요.

# %%
kor_sorted[0:20]
# Out:
#                                                Korean  \
# 0   의심의 여지 없이 세상에는 어떤 남자이든 정확히 딱 알맞는 여자와 결혼하거나 그 반...
# 1   일단의 토지면적이 특별시·광역시 및 시지역에서 1,000제곱미터 이하, 그 밖의 지...
# 2   제8조의2(과태료의 부과 및 징수) ① 제8조제1항의 요구를 받은 자가 이에 따를 ...
# 3   부칙 제2조「표 1」규정의 시행으로 감축되는 정원 27명(집행기관의 정원 27명)에...
# 4   「옥외광고물 등의 관리와 옥외광고산업 진흥에 관한 법률 시행령」(이하 “영”이라 한...
# 5   구청장은 신·재생에너지의 보급 확대를 위하여 행정재산 및 일반재산을 사용·수익허가 ...
# 6   “음식물류 폐기물 다량배출사업장”이란 「폐기물관리법 시행령」 제8조의4에서 정한 음...
# 7   이 조례에 따라 구세를 감면받고자 하는 자는 「지방세특례제한법 시행규칙」 별지 제1...
# 8   서울특별시 노원구청장(이하 “구청장”이라 한다)은 위임받은 서울특별시 시세(이하 “...
# 9   구청장은 「비영리민간단체지원법」에 따른 비영리 민간단체, 「민법」에 따른 비영리 법...
# 10  상품권이란 그 명칭 또는 형태에 관계없이 발행자가 일정한 금액이나 물품 또는 용역의...
# 11  세무조사를 실시하는 경우에는 조사개시 10일 전에 조사받을 납세의무자(법 제135조...
# 12  특례규정 제5조제2항제3호 및 제10조제2항제3호에 따라 필기시험을 면제할 수 있는...
# 13  납세자보호관은 세무조사 착수 후 납세자가 위반된 조사 등을 주장하는 경우 납세자가 ...
# 14  「국가기술자격법」 또는 그 밖의 법령에 따른 자격증 중에서 별표 3에서 정한 자격증...
# 15  「조세특례제한법」제121조의2제5항제2호 및 제3호에 따른 외국인투자비율에 해당하는...
# 16  (직급별 정원에 관한 경과조치) 이 규칙 시행으로 감축되는 공무원의 정원 200명에...
# 17  「부가가치세법」 제8조에 따라 건설업 또는 부동산매매업으로 등록을 한 주택건설사업자...
# 18  구청장으로부터 감사결과를 통보받은 감사대상기관의 장은 그 감사결과가 위법 또는 부당...
# 19  영 제17조제1항제4호 및 연구 및 지도직 규정 제6조에 따른 경력경쟁임용시험등의 ...
#
#                                               English  Korean_word_count  \
# 0   Doubtless there exists in this world precisely...                 89
# 1   Where land that has buildings that are not own...                 78
# 2   Article 8-2 (Imposition and Collection of Fine...                 71
# 3   Where there the current employees are in exces...                 64
# 4   Where filing an application for permission in ...                 62
# 5   In order to increase the supply of new and ren...                 61
# 6   The term "Business sites discharging large amo...                 59
# 7   Any person who intends to receive a reduction ...                 59
# 8   The head of Nowon-gu Seoul Metropolitan Govern...                 56
# 9   The head of the Gu may designate organizations...                 54
# 10  Merchandise coupons refer to securities for wh...                 52
# 11  Where conducting a tax investigation, the tax ...                 52
# 12  The classification of a qualification certific...                 52
# 13  If a taxpayer claims the existence of violated...                 52
# 14  When the certificate holder designated by atta...                 52
# 15  The amount of property tax falling under the f...                 52
# 16  (Transitional Measures concerning Number of Pe...                 51
# 17  A housing construction business operator who h...                 51
# 18  The head of an agency subject to audit, having...                 51
# 19  Qualifications for career-competitive examinat...                 50
#
#     English_word_count
# 0                  101
# 1                  165
# 2                  139
# 3                  158
# 4                  122
# 5                  133
# 6                  141
# 7                  148
# 8                  156
# 9                   99
# 10                  85
# 11                 127
# 12                 115
# 13                 110
# 14                  95
# 15                 180
# 16                  86
# 17                 152
# 18                  94
# 19                 107

# %% [markdown]
# ### (3) 영어 문장 단어 개수 파악

# %%
eng_sorted = data.sort_values(by=['English_word_count'], axis=0, ascending=False)

# %%
eng_sorted = eng_sorted.reset_index(drop=True)

# %%
eng_sorted[:20]
# Out:
#                                                Korean  \
# 0     제1항에 따른 포상금은 같은 신고자에게 연간 총 50만원을 초과하여 지급할 수 없다.
# 1   구청장은 구민의 문화교육 기회를 확대하기 위하여 각종 문화교육 프로그램을 운영하고,...
# 2   보호구역 관리책임자는 항시 출입자의 동태를 감시하고 안내와 통제 등 보안대책을 강구...
# 3   김철호(66) 신임 국립중앙극장장은 8일 서울 종로구 한 식당에서 열린 취임 기자간...
# 4   제1항에 따른 취업지원금 지급대상 기업 지정시 「근로기준법」 제11조와 「중소기업기...
# 5   필자는 운 좋게 그 박물관들 중 스미스소니언 자연사박물관에서 열리는 ‘아웃브레이크:...
# 6   구청장은 제2항에 의한 사육허가를 하는 경우 가축사육자에게 별지 제2호서식에 의한 ...
# 7                이들은 남북 정상이 함께 찍은 사진들을 길거리에 전시하기도 했다.
# 8       상담대상은 구에 주소 또는 거소를 둔 사람, 기업체 운영자, 근로자 등으로 한다.
# 9   「조세특례제한법」제121조의2제5항제2호 및 제3호에 따른 외국인투자비율에 해당하는...
# 10  「조세특례제한법」제121조의2제4항제1호 및 제2호에 따른 외국인투자비율에 해당하는...
# 11  일단의 토지면적이 특별시·광역시 및 시지역에서 1,000제곱미터 이하, 그 밖의 지...
# 12  부칙 제2조「표 1」규정의 시행으로 감축되는 정원 27명(집행기관의 정원 27명)에...
# 13  서울특별시 노원구청장(이하 “구청장”이라 한다)은 위임받은 서울특별시 시세(이하 “...
# 14  「부가가치세법」 제8조에 따라 건설업 또는 부동산매매업으로 등록을 한 주택건설사업자...
# 15  출연자들의 이러한 자세와 무대매너로 폭넓은 한국의 문화콘텐츠의 힘을 느낄 수 있었다...
# 16  도시주택실장은 지방이사관 또는 지방부이사관으로 임명하고, 도시정책관은 지방부이사관으...
# 17  이 조례에 따라 구세를 감면받고자 하는 자는 「지방세특례제한법 시행규칙」 별지 제1...
# 18  팀별로 보면 두산 베어스(OB 포함)와 삼성 라이온즈, 그리고 현대 유니콘스(삼미 ...
# 19  심의회의 위원은 기획조정실장, 안전관리실장, 도시주택실장, 공정국장, 자치행정국장,...
#
#                                               English  Korean_word_count  \
# 0   A                                             ...                 12
# 1   In order to expand cultural education opportun...                 17
# 2   The person in charge of the management of each...                 12
# 3   "We will play the role of a hub for inter-Kore...                 29
# 4   When designating an enterprise subject to paym...                 28
# 5   I was fortunate to be able to visit a special ...                 19
# 6   Where permitting breeding pursuant to paragrap...                 13
# 7   They also displayed photos taken by the leader...                  9
# 8   The subjects of counseling shall be those who ...                 12
# 9   The amount of property tax falling under the f...                 52
# 10  For the property tax falling under the foreign...                 46
# 11  Where land that has buildings that are not own...                 78
# 12  Where there the current employees are in exces...                 64
# 13  The head of Nowon-gu Seoul Metropolitan Govern...                 56
# 14  A housing construction business operator who h...                 51
# 15  The local response was that the performers cou...                 14
# 16  The head of an urban housing unit shall be app...                 18
# 17  Any person who intends to receive a reduction ...                 59
# 18  By team, Doosan Bears (including OB), Samsung ...                 20
# 19  The members of the Deliberative Council shall ...                 28
#
#     English_word_count
# 0                  993
# 1                  835
# 2                  728
# 3                  672
# 4                  638
# 5                  465
# 6                  353
# 7                  221
# 8                  190
# 9                  180
# 10                 172
# 11                 165
# 12                 158
# 13                 156
# 14                 152
# 15                 150
# 16                 150
# 17                 148
# 18                 146
# 19                 145

# %%
eng_sorted['English'][0]
# Out:
# 'A                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                '

# %%
eng_sorted['English'][1]
# Out:
# 'In order to expand cultural education opportunities for Gu residents, the head of the Gu may operate various cultural education programs and support related projects to facilitate such programs.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      '

# %%
eng_sorted['English'][2]
# Out:
# 'The person in charge of the management of each protected area shall constantly monitor the movement of visitors and take security measures, such as guidance and control.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             '

# %%
eng_sorted['English'][3]
# Out:
# '"We will play the role of a hub for inter-Korean exchanges of performing arts and culture," said Kim Cheol-ho, 66, the new director of the National Theater of Korea, at an inaugural press conference held at a restaurant in Jongro-gu, Seoul on the 8th and he said, "We can invite North Korean national art troupe for the festival that will be held in 2020 for the 70th anniversary of our foundation."                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         '

# %%
len(eng_sorted['English'][3].split(" "))
# Out:
# 672

# %%
len('"We will play the role of a hub for inter-Korean exchanges of performing arts and culture," said Kim Cheol-ho, 66, the new director of the National Theater of Korea, at an inaugural press conference held at a restaurant in Jongro-gu, Seoul on the 8th and he said, "We can invite North Korean national art troupe for the festival that will be held in 2020 for the 70th anniversary of our foundation."                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         '.split(" "))
# Out:
# 672

# %%
eng_sorted[-30:]
# Out:
#                                                     Korean  \
# 1603499  송정역에서 기자들과 만난 황 대표는 “우리나라는 한 나라인데 지역 간 갈등이 있었던...
# 1603500                                                뛰어.
# 1603501  필리핀과 대만 여자프로골프 투어가 공동 주관하는 이번 대회는 박성현의 메인 후원사인...
# 1603502  부구청장은 지방부이사관으로, 감사담당관은 지방행정사무관 또는 임기제 지방행정사무관(...
# 1603503  후배 세대에 ‘20대 개새끼론’을 펴던 이들은, 비난의 표적이 30대가 된 지금 새...
# 1603504                                               도와줘!
# 1603505                                                 가.
# 1603506  자신의 학과 및 자신의 업종과 관련이 있는 나라에서 이런 행사가 진행되고 더군다나 ...
# 1603507                                                 쏴!
# 1603508  최근 특검팀은 경공모 회원인 도아무개 변호사가 당시 5천만원 중 4190여만원이 되...
# 1603509       국가명, 도로명, 인근 지역, 아파트, 도시, 주 이름, 우편번호는 중요합니다.
# 1603510                                               고마워.
# 1603511                                               꼼짝마!
# 1603512  핫팟 가게에서 먹어 보았던 Fish ball의 퍼석한 식감과는 다른 한국 어묵만의 ...
# 1603513                                               기다려!
# 1603514                                               시작해.
# 1603515  춘절 당일 카퍼레이드 행진 등 공연을 마친 다음 꽃차를 침사추이 하버시티, 뉴월드센...
# 1603516                                              진심이야?
# 1603517                                              끝내주네!
# 1603518  이를 통하여 카자흐스탄의 영역을 포함한 광활한 유라시아 지역에서의 고대 문화가 서로...
# 1603519  김 위원장은 일몰 시한이 도래한 기업구조조정촉진법에 대해서는 “기업구조조정촉진법의 ...
# 1603520  지난 3일 검찰이 구속영장을 청구한 박병대·고영한 전 대법관의 구속 전 피의자심문(...
# 1603521                                                설마!
# 1603522                                                우와!
# 1603523                        그러니 9월 8일에 일괄로 보내주셔도 괜찮습니다.
# 1603524                                               절대로!
# 1603525                                               굉장해!
# 1603526  한인 행사 때도 120명이 모인다고 하면 정말 많은 사람이 모인 거라고 할 수 있는...
# 1603527  최서윤 미세먼지를 중국 탓만 할 수 없고 우리가 할 수 있는 것에 대한 점검이 필요...
# 1603528  특히 다른 익인들에 비해 절반 크기에 불과한 비오의 날개에는 고원 지대와 도시 사이...
#
#                                                    English  Korean_word_count  \
# 1603499                                                  z                 20
# 1603500                                               Run.                  1
# 1603501                                                  x                 19
# 1603502                                               보한다?                 10
# 1603503                                                  x                 16
# 1603504                                              Help!                  1
# 1603505                                                Go.                  1
# 1603506                                                 비문                 29
# 1603507                                              Fire!                  1
# 1603508                                               ----                 25
# 1603509  Country,Street,Neighborhood,Apartment,City,Sta...                 10
# 1603510                                            Thanks.                  1
# 1603511                                            Freeze!                  1
# 1603512                                                  .                 26
# 1603513                                              Wait!                  1
# 1603514                                             Begin.                  1
# 1603515                                                  '                 20
# 1603516                                         Seriously?                  1
# 1603517                                         Fantastic!                  1
# 1603518                                                  T                 27
# 1603519                                              -----                 20
# 1603520                                                  .                 21
# 1603521                                      Unbelievable!                  1
# 1603522                                               Wow!                  1
# 1603523                                                  .                  6
# 1603524                                        Definitely!                  1
# 1603525                                           Awesome!                  1
# 1603526                                                  .                 26
# 1603527                                                  x                 19
# 1603528                                                  x                 17
#
#          English_word_count
# 1603499                   1
# 1603500                   1
# 1603501                   1
# 1603502                   1
# 1603503                   1
# 1603504                   1
# 1603505                   1
# 1603506                   1
# 1603507                   1
# 1603508                   1
# 1603509                   1
# 1603510                   1
# 1603511                   1
# 1603512                   1
# 1603513                   1
# 1603514                   1
# 1603515                   1
# 1603516                   1
# 1603517                   1
# 1603518                   1
# 1603519                   1
# 1603520                   1
# 1603521                   1
# 1603522                   1
# 1603523                   1
# 1603524                   1
# 1603525                   1
# 1603526                   1
# 1603527                   1
# 1603528                   1

# %% [markdown]
# 한글 데이터는 짧은 문장의 경우 띄어쓰기가 잘 안 이루어져 있음.
# 영어 데이터는 긴 문장의 경우 띄어쓰기가 지나치게 많이 들어가 있음.
# 짧은 문장의 경우 검수 안된 문장들 . 혹은 x 등 많음.

# %% [markdown]
# ## 4. 박스플롯 그려보기

# %%
print("한글 문장 중 가장 적은 단어 개수 가진 문장은 ", min(kor_word_cnt))
print("한글 문장 중 가장 많은 단어 개수 가진 문장은 ", max(kor_word_cnt))
print("영어 문장 중 가장 적은 단어 개수 가진 문장은 ", min(eng_word_cnt))
print("영어 문장 중 가장 많은 단어 개수 가진 문장은 ", max(eng_word_cnt))
# Out:
# 한글 문장 중 가장 적은 단어 개수 가진 문장은  1
# 한글 문장 중 가장 많은 단어 개수 가진 문장은  89
# 영어 문장 중 가장 적은 단어 개수 가진 문장은  1
# 영어 문장 중 가장 많은 단어 개수 가진 문장은  993

# %%
fig, ax = plt.subplots(figsize = (12,8))
sns.boxplot(kor_word_cnt)
plt.show()

# %%
fig, ax = plt.subplots(figsize = (12,8))
sns.boxplot(eng_word_cnt)
plt.show()
